# %%
 #Transpose.
from PIL import Image
  
def main():
    try:
        #Relative Path
        img = Image.open("picture.jpg") 
        #transposing image 
        transposed_img = img.transpose(Image.FLIP_LEFT_RIGHT)  
        #Save transposed image
        transposed_img.save("transposed.jpg")
    except IOError:
        pass
  
if __name__ == "__main__":
    main()
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=3290x4112 at 0x13953EAF880>

# %%
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
  
# Read Images
original_img = mpimg.imread('picture.jpg')
plt.imshow(original_img)

# %%
# Read Images
transposed_img = mpimg.imread('transposed.jpg')  
plt.imshow(transposed_img)

# %%
from numpy import array
img = Image.open(r"picture.jpg")
mat = array(img)
mat
# Out:
# array([[[12, 30, 34],
#         [14, 29, 34],
#         [14, 29, 34],
#         ...,
#         [21, 22, 24],
#         [21, 22, 24],
#         [21, 22, 24]],
#
#        [[14, 29, 34],
#         [14, 29, 34],
#         [13, 28, 33],
#         ...,
#         [21, 22, 24],
#         [21, 22, 24],
#         [21, 22, 24]],
#
#        [[14, 29, 34],
#         [13, 28, 33],
#         [14, 28, 31],
#         ...,
#         [21, 22, 24],
#         [21, 22, 24],
#         [21, 22, 24]],
#
#        ...,
#
#        [[21, 32, 38],
#         [21, 32, 38],
#         [21, 32, 38],
#         ...,
#         [24, 33, 38],
#         [24, 33, 38],
#         [24, 33, 38]],
#
#        [[21, 32, 38],
#         [21, 32, 38],
#         [21, 32, 38],
#         ...,
#         [25, 34, 39],
#         [23, 32, 37],
#         [23, 32, 37]],
#
#        [[21, 32, 38],
#         [21, 32, 38],
#         [21, 32, 38],
#         ...,
#         [25, 34, 39],
#         [23, 32, 37],
#         [23, 32, 37]]], dtype=uint8)

# %%
mat.shape
# Out:
# (4112, 3290, 3)

# %%
#Check if the matrix is one or many of the special types we have seen (diagonal, triagonal...).

# %%
#Choose a column vector and calculate both norms that we’ve seen.
