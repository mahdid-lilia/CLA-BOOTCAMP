# %%
#**************** Data Cleaning and Preparation Homework *********************
import pandas as pd 
df = pd.read_csv("videosUS.csv")
df.head()
# Out:
#       video_id trending_date  \
# 0  2kyS6SvSYSE      17.14.11
# 1  1ZAPwfrtAFY      17.14.11
# 2  5qpjK5DgCt4      17.14.11
# 3  puqaWrEC7tY      17.14.11
# 4  d380meD0W0M      17.14.11
#
#                                                title          channel_title  \
# 0                 WE WANT TO TALK ABOUT OUR MARRIAGE           CaseyNeistat
# 1  The Trump Presidency: Last Week Tonight with J...        LastWeekTonight
# 2  Racist Superman | Rudy Mancuso, King Bach & Le...           Rudy Mancuso
# 3                   Nickelback Lyrics: Real or Fake?  Good Mythical Morning
# 4                           I Dare You: GOING BALD!?               nigahiga
#
#    category_id              publish_time  \
# 0         22.0  2017-11-13T17:13:01.000Z
# 1         24.0  2017-11-13T07:30:00.000Z
# 2         23.0  2017-11-12T19:05:24.000Z
# 3         24.0  2017-11-13T11:00:04.000Z
# 4         24.0  2017-11-12T18:01:41.000Z
#
# ...

# %%
#Find out how many missing values you have within your dataset?
#Which columns ? What assumptions can you make about these missing values ( why do we have them missing ? )
df.isna()
# Out:
#        video_id  trending_date  title  channel_title  category_id  \
# 0         False          False  False          False        False
# 1         False          False  False          False        False
# 2         False          False  False          False        False
# 3         False          False  False          False        False
# 4         False          False  False          False        False
# ...         ...            ...    ...            ...          ...
# 41410     False          False  False          False        False
# 41411     False          False  False          False        False
# 41412     False          False  False          False        False
# 41413     False          False  False          False        False
# 41414     False          False  False          False        False
#
#        publish_time   tags  views  likes  dislikes  comment_count  \
# 0             False  False  False  False     False          False
# ...

# %%
#number of missing values I have within my dataset
df.isna().sum().sum()
# Out:
# 7560

# %%
#columns
df.isnull().sum()
# Out:
# video_id                     0
# trending_date              466
# title                      466
# channel_title              466
# category_id                466
# publish_time               466
# tags                       466
# views                      466
# likes                      466
# dislikes                   466
# comment_count              466
# thumbnail_link             466
# comments_disabled          466
# ratings_disabled           466
# video_error_or_removed     466
# description               1036
# dtype: int64

# %%
df[df.trending_date.isnull()]
# Out:
#                                                 video_id trending_date title  \
# 53     \nSubscribe to WWE on YouTube: http://bit.ly/1...           NaN   NaN
# 54                 \nVisit WWE.com: http://goo.gl/akf0J4           NaN   NaN
# 55     \nMust-See WWE videos on YouTube: https://goo....           NaN   NaN
# 319    \nSubscribe to WWE on YouTube: http://bit.ly/1...           NaN   NaN
# 320                \nVisit WWE.com: http://goo.gl/akf0J4           NaN   NaN
# ...                                                  ...           ...   ...
# 36570  Follow me on Twitter ► https://twitter.com/mar...           NaN   NaN
# 36571  Like me on Facebook ► https://www.facebook.com...           NaN   NaN
# 36572  Join us on Reddit! ► https://www.reddit.com/r/...           NaN   NaN
# 36573  Horror Outro ► https://soundcloud.com/shurkoff...           NaN   NaN
# 36574  Happy Outro ► https://soundcloud.com/hielia/mi...           NaN   NaN
#
# ...

# %%
# Compute the mean value
# Compute the mean value
df.mean(axis = 0)
# Out:
# C:\Users\hp\AppData\Local\Temp/ipykernel_3280/1214280050.py:3: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.mean(axis = 0)
# category_id               1.997243e+01
# views                     2.360785e+06
# likes                     7.426670e+04
# dislikes                  3.711401e+03
# comment_count             8.446804e+03
# comments_disabled         1.545825e-02
# ratings_disabled          4.127085e-03
# video_error_or_removed    5.616743e-04
# dtype: float64

# %%
df.median()
# Out:
# C:\Users\hp\AppData\Local\Temp/ipykernel_3280/530051474.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.median()
# category_id                   24.0
# views                     681861.0
# likes                      18091.0
# dislikes                     631.0
# comment_count               1856.0
# comments_disabled              0.0
# ratings_disabled               0.0
# video_error_or_removed         0.0
# dtype: float64

# %%
# Function to give index of the median
import pandas as pd 
def median(a, l, r):
    n = r - l + 1
    n = (n + 1) // 2 - 1
    return n + l
 
# Function to calculate IQR
def IQR(a, n):
 
    a.sort_values()
 
    # Index of median of entire data
    mid_index = median(a, 0, n)
 
    # Median of first half
    Q1 = a[median(a, 0, mid_index)]
 
    # Median of second half
    Q3 = a[mid_index + median(a, mid_index + 1, n)]
 
    # IQR calculation
    return (Q3 - Q1)
 # Driver Function
if __name__=='__main__':
    a = df.views
    n = len(a)
    print(IQR(a, n))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\range.py in get_loc(self, key, method, tolerance)
#     384                 try:
# --> 385                     return self._range.index(new_key)
#     386                 except ValueError as err:
#
# ValueError: 51768 is not in range
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_5552/2024800102.py in <module>
#      26     a = df.views
#      27     n = len(a)
# ---> 28     print(IQR(a, n))
#
# ~\AppData\Local\Temp/ipykernel_5552/2024800102.py in IQR(a, n)
#      18
#      19     # Median of second half
# ---> 20     Q3 = a[mid_index + median(a, mid_index + 1, n)]
#      21
#      22     # IQR calculation
#
# ...

# %%
df = pd.read_csv("videosUS.csv")
df["views_zscore"]=(df.views - df.views.mean())/ df.views.std()
df=df[df["views_zscore"]>3]
df[df["views_zscore"]>3]
# Out:
#           video_id trending_date  \
# 73     2Vv-BfVoq4g      17.14.11
# 342    2Vv-BfVoq4g      17.15.11
# 583    2Vv-BfVoq4g      17.16.11
# 778    n1WpP7iowLc      17.17.11
# 1010   n1WpP7iowLc      17.18.11
# ...            ...           ...
# 41335  xTlNMmZKwpA      18.14.06
# 41341  1J76wN0TPI4      18.14.06
# 41373  aEM2kOrrNJI      18.14.06
# 41391  QgOXIEhHU1Y      18.14.06
# 41404  n_W54baizX8      18.14.06
#
#                                                    title      channel_title  \
# 73           Ed Sheeran - Perfect (Official Music Video)         Ed Sheeran
# 342          Ed Sheeran - Perfect (Official Music Video)         Ed Sheeran
# 583          Ed Sheeran - Perfect (Official Music Video)         Ed Sheeran
# 778           Eminem - Walk On Water (Audio) ft. Beyoncé         EminemVEVO
# 1010          Eminem - Walk On Water (Audio) ft. Beyoncé         EminemVEVO
# ...                                                  ...                ...
# ...

# %%
df = pd.read_csv("videosUS.csv")
df["dislikes_zscore"]=(df.dislikes- df.dislikes.mean())/ df.dislikes.std()
df=df[df["dislikes_zscore"]>3]
df[df["dislikes_zscore"]>3]
# Out:
#           video_id trending_date  \
# 1974   TyHvyGVs42U      17.23.11
# 2175   TyHvyGVs42U      17.24.11
# 2389   TyHvyGVs42U      17.25.11
# 2612   TyHvyGVs42U      17.26.11
# 4630   FlsCjmMhFmw      17.07.12
# ...            ...           ...
# 41275  GnGPAYvve1A      18.14.06
# 41290  J2HytHu5VBI      18.14.06
# 41335  xTlNMmZKwpA      18.14.06
# 41342  Tn8hOPeAnIM      18.14.06
# 41414  ooyjaVdt-jA      18.14.06
#
#                                                    title      channel_title  \
# 1974           Luis Fonsi, Demi Lovato - Échame La Culpa      LuisFonsiVEVO
# 2175           Luis Fonsi, Demi Lovato - Échame La Culpa      LuisFonsiVEVO
# 2389           Luis Fonsi, Demi Lovato - Échame La Culpa      LuisFonsiVEVO
# 2612           Luis Fonsi, Demi Lovato - Échame La Culpa      LuisFonsiVEVO
# 4630   YouTube Rewind: The Shape of 2017 | #YouTubeRe...  YouTube Spotlight
# ...                                                  ...                ...
# ...

# %%
df = pd.read_csv("videosUS.csv")
df["likes_zscore"]=(df.likes - df.likes.mean())/ df.likes.std()
df=df[df["likes_zscore"]>3]
df[df["likes_zscore"]>3]
# Out:
#           video_id trending_date  \
# 32     n1WpP7iowLc      17.14.11
# 73     2Vv-BfVoq4g      17.14.11
# 152    9wg3v-01yKQ      17.14.11
# 301    n1WpP7iowLc      17.15.11
# 342    2Vv-BfVoq4g      17.15.11
# ...            ...           ...
# 41321  D_6QmL6rExk      18.14.06
# 41335  xTlNMmZKwpA      18.14.06
# 41341  1J76wN0TPI4      18.14.06
# 41362  nQySbNGu4g0      18.14.06
# 41391  QgOXIEhHU1Y      18.14.06
#
#                                                    title    channel_title  \
# 32            Eminem - Walk On Water (Audio) ft. Beyoncé       EminemVEVO
# 73           Ed Sheeran - Perfect (Official Music Video)       Ed Sheeran
# 152                                  Harry Styles - Kiwi  HarryStylesVEVO
# 301           Eminem - Walk On Water (Audio) ft. Beyoncé       EminemVEVO
# 342          Ed Sheeran - Perfect (Official Music Video)       Ed Sheeran
# ...                                                  ...              ...
# ...

# %%
df = pd.read_csv("videosUS.csv")
df["category_id_zscore"]=(df.category_id - df.category_id.mean())/ df.category_id.std()
df=df[df["category_id_zscore"]>3]
df[df["category_id_zscore"]>3]
# Out:
#           video_id trending_date  \
# 7929   lM0yu7c6lQk      17.23.12
# 8152   lM0yu7c6lQk      17.24.12
# 8359   lM0yu7c6lQk      17.25.12
# 8564   lM0yu7c6lQk      17.26.12
# 8777   lM0yu7c6lQk      17.27.12
# 9002   lM0yu7c6lQk      17.28.12
# 9216   lM0yu7c6lQk      17.29.12
# 9432   lM0yu7c6lQk      17.30.12
# 9653   lM0yu7c6lQk      17.31.12
# 9857   lM0yu7c6lQk      18.01.01
# 10065  lM0yu7c6lQk      18.02.01
# 14488  Q1CFfU2gXHw      18.26.01
# 14713  Q1CFfU2gXHw      18.27.01
# 14928  Q1CFfU2gXHw      18.28.01
# 15161  Q1CFfU2gXHw      18.29.01
# 15407  Q1CFfU2gXHw      18.30.01
# 28884  7_FJUSBFbJM      18.14.04
# 29100  7_FJUSBFbJM      18.15.04
# 29316  7_FJUSBFbJM      18.16.04
# 29532  7_FJUSBFbJM      18.17.04
# 29744  7_FJUSBFbJM      18.18.04
# 29957  7_FJUSBFbJM      18.19.04
# 30165  7_FJUSBFbJM      18.20.04
# 30383  7_FJUSBFbJM      18.21.04
# 30599  7_FJUSBFbJM      18.22.04
# 30812  7_FJUSBFbJM      18.23.04
# 31022  7_FJUSBFbJM      18.24.04
# ...

# %%
df = pd.read_csv("videosUS.csv")
df["comment_count_zscore"]=(df.comment_count - df.comment_count.mean())/ df.comment_count.std()
df=df[df["comment_count_zscore"]>3]
df[df["comment_count_zscore"]>3]
# Out:
#           video_id trending_date  \
# 32     n1WpP7iowLc      17.14.11
# 301    n1WpP7iowLc      17.15.11
# 543    n1WpP7iowLc      17.16.11
# 778    n1WpP7iowLc      17.17.11
# 1010   n1WpP7iowLc      17.18.11
# ...            ...           ...
# 41114  D_6QmL6rExk      18.13.06
# 41208  ooyjaVdt-jA      18.13.06
# 41290  J2HytHu5VBI      18.14.06
# 41321  D_6QmL6rExk      18.14.06
# 41414  ooyjaVdt-jA      18.14.06
#
#                                                    title channel_title  \
# 32            Eminem - Walk On Water (Audio) ft. Beyoncé    EminemVEVO
# 301           Eminem - Walk On Water (Audio) ft. Beyoncé    EminemVEVO
# 543           Eminem - Walk On Water (Audio) ft. Beyoncé    EminemVEVO
# 778           Eminem - Walk On Water (Audio) ft. Beyoncé    EminemVEVO
# 1010          Eminem - Walk On Water (Audio) ft. Beyoncé    EminemVEVO
# ...                                                  ...           ...
# ...

# %%
df = pd.read_csv("videosUS.csv")
df["comments_disabled_zscore"]=(df.comments_disabled - df.comments_disabled.mean())/ df.comments_disabled.std()
df=df[df["comments_disabled_zscore"]>3]
df[df["comments_disabled_zscore"]>3]
# Out:
#           video_id trending_date  \
# 31     CBVGjS_EJok      17.14.11
# 106    9oFP-pOMNwE      17.14.11
# 293    CBVGjS_EJok      17.15.11
# 378    9oFP-pOMNwE      17.15.11
# 492    Hq89wYzOjfs      17.16.11
# ...            ...           ...
# 41015  FchkqXEg0qs      18.13.06
# 41090  J2m7EUwnqGg      18.13.06
# 41097  lBbSzQXQknw      18.13.06
# 41298  J2m7EUwnqGg      18.14.06
# 41305  lBbSzQXQknw      18.14.06
#
#                                                    title  \
# 31           Amazon Christmas Advert 2017 - Toys & Games
# 106    H&M Holiday 2017 starring Nicki Minaj – offici...
# 293          Amazon Christmas Advert 2017 - Toys & Games
# 378    H&M Holiday 2017 starring Nicki Minaj – offici...
# 492    Amazon CEO Jeff Bezos and brother Mark give a ...
# ...                                                  ...
# 41015                          Nintendo @ E3 2018: Day 1
# 41090            iPhone X — Animoji: Taxi Driver — Apple
# ...

# %%
df = pd.read_csv("videosUS.csv")
df["ratings_disabled_zscore"]=(df.ratings_disabled - df.ratings_disabled.mean())/ df.ratings_disabled.std()
df=df[df["ratings_disabled_zscore"]>3]
df[df["ratings_disabled_zscore"]>3]
# Out:
#           video_id trending_date  \
# 1456   Kn5UgGQukYQ      17.21.11
# 1691   Kn5UgGQukYQ      17.22.11
# 1892   _akwfRuL4os      17.23.11
# 1938   Kn5UgGQukYQ      17.23.11
# 2105   _akwfRuL4os      17.24.11
# ...            ...           ...
# 28454  UwbO_xb1-Xo      18.05.04
# 28665  UwbO_xb1-Xo      18.06.04
# 28869  9TUBf6l7FBg      18.14.04
# 29070  9TUBf6l7FBg      18.15.04
# 29274  9TUBf6l7FBg      18.16.04
#
#                                                    title        channel_title  \
# 1456   Breaking Bad's Bryan Cranston on Meeting Charl...   hudsonunionsociety
# 1691   Breaking Bad's Bryan Cranston on Meeting Charl...   hudsonunionsociety
# 1892   Highlights of the EA predatory behavior announ...            chris lee
# 1938   Breaking Bad's Bryan Cranston on Meeting Charl...   hudsonunionsociety
# 2105   Highlights of the EA predatory behavior announ...            Chris Lee
# ...                                                  ...                  ...
# ...

# %%
df = pd.read_csv("videosUS.csv")
df["video_error_or_removed_zscore"]=(df.video_error_or_removed - df.video_error_or_removed.mean())/ df.video_error_or_removed.std()
df=df[df["video_error_or_removed_zscore"]>3]
df[df["video_error_or_removed_zscore"]>3]
# Out:
#           video_id trending_date  \
# 2227   RK_B4Ez4_5Q      17.25.11
# 15719  kZete48ZtsY      18.01.02
# 15978  kZete48ZtsY      18.02.02
# 16206  kZete48ZtsY      18.03.02
# 30679  q8v9MvManKE      18.23.04
# 30896  q8v9MvManKE      18.24.04
# 31110  q8v9MvManKE      18.25.04
# 31322  q8v9MvManKE      18.26.04
# 31537  q8v9MvManKE      18.27.04
# 31754  q8v9MvManKE      18.28.04
# 31960  q8v9MvManKE      18.29.04
# 32180  q8v9MvManKE      18.30.04
# 32393  q8v9MvManKE      18.01.05
# 32612  q8v9MvManKE      18.02.05
# 32829  q8v9MvManKE      18.03.05
# 33040  q8v9MvManKE      18.04.05
# 33092  1Aoc-cd9eYs      18.05.05
# 33308  1Aoc-cd9eYs      18.06.05
# 33527  1Aoc-cd9eYs      18.07.05
# 33766  1Aoc-cd9eYs      18.08.05
# 33984  1Aoc-cd9eYs      18.09.05
# 34213  1Aoc-cd9eYs      18.10.05
# 35006  1Aoc-cd9eYs      18.14.05
#
#                                                    title  \
# 2227   Verizon 360 Live: The Macy’s Thanksgiving Day ...
# ...

# %%
 df['views'].unique()
# Out:
# array([2.6183440e+06, 6.0262000e+04, 2.6110000e+03, 2.6200000e+03,
#        3.9792000e+05, 1.6813500e+05, 2.1862100e+05, 8.7590100e+05,
#        3.9303350e+06, 4.1755760e+06, 4.3995060e+06, 1.1576310e+06,
#        1.1845180e+06, 1.2049070e+06, 1.1979805e+07, 1.2339550e+06,
#        8.3302700e+05, 6.4105500e+05, 6.7260900e+05, 4.1232300e+05,
#        2.5185700e+05, 6.2905500e+05, 1.0624990e+06])

# %%
y= pd.get_dummies(df.Genre, prefix='Genre')
print(y)

# %%
from scipy import stats
import numpy as np
z = np.abs(stats.zscore(df.views))
print(z)
# Out:
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
#          ..
# 41410   NaN
# 41411   NaN
# 41412   NaN
# 41413   NaN
# 41414   NaN
# Name: views, Length: 41415, dtype: float64

# %%
threshold = 3
print(np.where(z > 3))
# Out:
# (array([], dtype=int64),)

# %%
daa= pd.read_csv("videosUS.csv")
daa.views = daa.views[(z < 3).all(axis=0)]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_5552/1199286515.py in <module>
#       1 daa= pd.read_csv("videosUS.csv")
# ----> 2 daa.views = daa.views[(z < 3).all(axis=0)]
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     940
#     941         elif key_is_scalar:
# --> 942             return self._get_value(key)
#     943
#     944         if is_hashable(key):
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in _get_value(self, label, takeable)
#    1049
#    1050         # Similar to Index.get_value, but we do not fall back to positional
# -> 1051         loc = self.index.get_loc(label)
#    1052         return self.index._get_values_for_loc(self, loc, label)
#    1053
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\range.py in get_loc(self, key, method, tolerance)
# ...
