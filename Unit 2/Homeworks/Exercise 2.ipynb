# %%
#**************** Data Cleaning and Preparation Homework *********************
import pandas as pd 
df = pd.read_csv("videosUS.csv")
df.head()
# Out:
#       video_id trending_date  \
# 0  2kyS6SvSYSE      17.14.11
# 1  1ZAPwfrtAFY      17.14.11
# 2  5qpjK5DgCt4      17.14.11
# 3  puqaWrEC7tY      17.14.11
# 4  d380meD0W0M      17.14.11
#
#                                                title          channel_title  \
# 0                 WE WANT TO TALK ABOUT OUR MARRIAGE           CaseyNeistat
# 1  The Trump Presidency: Last Week Tonight with J...        LastWeekTonight
# 2  Racist Superman | Rudy Mancuso, King Bach & Le...           Rudy Mancuso
# 3                   Nickelback Lyrics: Real or Fake?  Good Mythical Morning
# 4                           I Dare You: GOING BALD!?               nigahiga
#
#    category_id              publish_time  \
# 0         22.0  2017-11-13T17:13:01.000Z
# 1         24.0  2017-11-13T07:30:00.000Z
# 2         23.0  2017-11-12T19:05:24.000Z
# 3         24.0  2017-11-13T11:00:04.000Z
# 4         24.0  2017-11-12T18:01:41.000Z
#
# ...

# %%
#Find out how many missing values you have within your dataset?
#Which columns ? What assumptions can you make about these missing values ( why do we have them missing ? )
df.isna()
# Out:
#        video_id  trending_date  title  channel_title  category_id  \
# 0         False          False  False          False        False
# 1         False          False  False          False        False
# 2         False          False  False          False        False
# 3         False          False  False          False        False
# 4         False          False  False          False        False
# ...         ...            ...    ...            ...          ...
# 41410     False          False  False          False        False
# 41411     False          False  False          False        False
# 41412     False          False  False          False        False
# 41413     False          False  False          False        False
# 41414     False          False  False          False        False
#
#        publish_time   tags  views  likes  dislikes  comment_count  \
# 0             False  False  False  False     False          False
# ...

# %%
#number of missing values I have within my dataset
df.isna().sum().sum()
# Out:
# 7560

# %%
#columns
df.isnull().sum()
# Out:
# video_id                     0
# trending_date              466
# title                      466
# channel_title              466
# category_id                466
# publish_time               466
# tags                       466
# views                      466
# likes                      466
# dislikes                   466
# comment_count              466
# thumbnail_link             466
# comments_disabled          466
# ratings_disabled           466
# video_error_or_removed     466
# description               1036
# dtype: int64

# %%
df[df.trending_date.isnull()]
# Out:
#                                                 video_id trending_date title  \
# 53     \nSubscribe to WWE on YouTube: http://bit.ly/1...           NaN   NaN
# 54                 \nVisit WWE.com: http://goo.gl/akf0J4           NaN   NaN
# 55     \nMust-See WWE videos on YouTube: https://goo....           NaN   NaN
# 319    \nSubscribe to WWE on YouTube: http://bit.ly/1...           NaN   NaN
# 320                \nVisit WWE.com: http://goo.gl/akf0J4           NaN   NaN
# ...                                                  ...           ...   ...
# 36570  Follow me on Twitter ► https://twitter.com/mar...           NaN   NaN
# 36571  Like me on Facebook ► https://www.facebook.com...           NaN   NaN
# 36572  Join us on Reddit! ► https://www.reddit.com/r/...           NaN   NaN
# 36573  Horror Outro ► https://soundcloud.com/shurkoff...           NaN   NaN
# 36574  Happy Outro ► https://soundcloud.com/hielia/mi...           NaN   NaN
#
# ...

# %%
# Compute the mean value
# Compute the mean value
df.mean(axis = 0)
# Out:
# C:\Users\hp\AppData\Local\Temp/ipykernel_3280/1214280050.py:3: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.mean(axis = 0)
# category_id               1.997243e+01
# views                     2.360785e+06
# likes                     7.426670e+04
# dislikes                  3.711401e+03
# comment_count             8.446804e+03
# comments_disabled         1.545825e-02
# ratings_disabled          4.127085e-03
# video_error_or_removed    5.616743e-04
# dtype: float64

# %%
df.median()
# Out:
# C:\Users\hp\AppData\Local\Temp/ipykernel_3280/530051474.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.median()
# category_id                   24.0
# views                     681861.0
# likes                      18091.0
# dislikes                     631.0
# comment_count               1856.0
# comments_disabled              0.0
# ratings_disabled               0.0
# video_error_or_removed         0.0
# dtype: float64

# %%
min = .min(axis=0)
q1 = .quantile(x, .25)
median = np.median(x)
q3 = np.quantile(x, .75)
max = np.max(x)
print(min, q1, median, q3, max)

# %%
da = pd.read_csv("videosUS.csv")
da["views_zscore"]=(da.views - da.views.mean())/ da.views.std()
da=da[da["views_zscore"]>3]
da[da["views_zscore"]>3]
# Out:
#           video_id trending_date  \
# 73     2Vv-BfVoq4g      17.14.11
# 342    2Vv-BfVoq4g      17.15.11
# 583    2Vv-BfVoq4g      17.16.11
# 778    n1WpP7iowLc      17.17.11
# 1010   n1WpP7iowLc      17.18.11
# ...            ...           ...
# 41335  xTlNMmZKwpA      18.14.06
# 41341  1J76wN0TPI4      18.14.06
# 41373  aEM2kOrrNJI      18.14.06
# 41391  QgOXIEhHU1Y      18.14.06
# 41404  n_W54baizX8      18.14.06
#
#                                                    title      channel_title  \
# 73           Ed Sheeran - Perfect (Official Music Video)         Ed Sheeran
# 342          Ed Sheeran - Perfect (Official Music Video)         Ed Sheeran
# 583          Ed Sheeran - Perfect (Official Music Video)         Ed Sheeran
# 778           Eminem - Walk On Water (Audio) ft. Beyoncé         EminemVEVO
# 1010          Eminem - Walk On Water (Audio) ft. Beyoncé         EminemVEVO
# ...                                                  ...                ...
# ...

# %%
from scipy import stats
import numpy as np
z = np.abs(stats.zscore(df.views))
print(z)
# Out:
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
#          ..
# 41410   NaN
# 41411   NaN
# 41412   NaN
# 41413   NaN
# 41414   NaN
# Name: views, Length: 41415, dtype: float64

# %%
threshold = 3
print(np.where(z > 3))
# Out:
# (array([], dtype=int64),)

# %%
da.views = da.views[(z < 3).all(axis=0)]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index_class_helper.pxi in pandas._libs.index.Int64Engine._check_type()
#
# pandas\_libs\index_class_helper.pxi in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: False
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_3280/1745842804.py in <module>
# ----> 1 da.views = da.views[(z < 3).all(axis=0)]
#
# ...
